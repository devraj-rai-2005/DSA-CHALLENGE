# %% [markdown]
# ## METHOD 1 APPROACH

# %%
num = [1,2,3,4,5,0,1,3,4,4,5,54,544,32,23,4,4,23,2,4,23,1,3,21,43,54,1,2,32,15,6,6,3,11,5,13,23,31,31,3,31,31,7]

ls = num

frq_map = dict()

for i in range(len(num)):
    if num[i] in frq_map:
        frq_map[num[i]] +=1
    else :
        frq_map[num[i]] = 1
frq_map
# Out:
# {1: 4,
#  2: 3,
#  3: 5,
#  4: 6,
#  5: 3,
#  0: 1,
#  54: 2,
#  544: 1,
#  32: 2,
#  23: 4,
#  21: 1,
#  43: 1,
#  15: 1,
#  6: 2,
#  11: 1,
#  13: 1,
#  31: 4,
#  7: 1}

# %% [markdown]
# ## Method 2

# %%
num = [1,2,3,4,5,0,1,3,4,4,5,54,544,32,23,4,4,23,2,4,23,1,3,21,43,54,1,2,32,15,6,6,3,11,5,13,23,31,31,3,31,31,7]

ls = num 

map = dict()

for i in range(0 , len(ls)):
    
    map[ls[i]] = map.get(ls[i] , 0)+1
    
map
# Out:
# {1: 4,
#  2: 3,
#  3: 5,
#  4: 6,
#  5: 3,
#  0: 1,
#  54: 2,
#  544: 1,
#  32: 2,
#  23: 4,
#  21: 1,
#  43: 1,
#  15: 1,
#  6: 2,
#  11: 1,
#  13: 1,
#  31: 4,
#  7: 1}
