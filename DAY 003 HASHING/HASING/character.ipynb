# %%
s = "azyxyyzaaaaAZQWERD"
q = ["a" , "a" , "y" , "x" ,"D" , "A"]

freq = {}
ans = {}

for num in s : 
    freq[num] = freq.get(num , 0) +1
for n in q:
    ans[n] = freq.get(n , 0)
ans
# Out:
# {'a': 5, 'y': 3, 'x': 1, 'D': 1, 'A': 1}

# %%
# Out:
# 97
