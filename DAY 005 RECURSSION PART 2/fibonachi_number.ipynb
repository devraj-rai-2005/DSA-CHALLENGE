# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def func( n ):
    if n == 0 :
        return 0 
    if n == 1 :
        return 1 
    return  func(n= n-1) + func(n = n-2)

# %%
func(n=9)
# Out:
# 34
