# %% [markdown]
# ### Ascending

# %%
num = [5,7,8,4,1,6,9,2]
arr  = num

def asc_sort(arr) :
    n = len(arr)
    for i in range(0 , n) :
        min_index = i
        for j in range(i+1 , n) :
            if arr[j] < arr[min_index] : 
                min_index = j
        arr[i] , arr[min_index] = arr[min_index], arr[i]
    return arr

asc_sort(arr = arr)
# Out:
# [1, 2, 4, 5, 6, 7, 8, 9]

# %% [markdown]
# ## Descending

# %%
num = [5,7,8,4,1,6,9,2]
arr  = num

def asc_sort(arr) :
    n = len(arr)
    for i in range(0 , n) :
        min_index = i
        for j in range(i+1 , n) :
            if arr[j] >  arr[min_index] : 
                min_index = j
        arr[i] , arr[min_index] = arr[min_index], arr[i]
    return arr

asc_sort(arr = arr)
# Out:
# [9, 8, 7, 6, 5, 4, 2, 1]
