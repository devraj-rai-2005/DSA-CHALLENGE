# %%
num = 1234
result = 0

# %%
n = num 

d1 = n%10
n1 = n//10
d2 = n1%10
l1 = d1*10+d2
n2 = n1//10
d3 = n2%10
l2 = l1*10+d3
n3 = n2//10
d4 = n3%10
l3 = l2*10+d4
n4 = n3//10

n == l3
# Out:
# False

# %%
n= 121
num = n
result = 0

while num > 0:
    d = num%10
    result = (result * 10) + d
    num = num//10
result == n
# Out:
# True
