# %%
number = 18904

while number > 0 :
    last = number%10
    print(last)
    number = number//10
# Out:
# 4
# 0
# 9
# 8
# 1

# %%
num = 123

while num > 0 :
    last_digit = num%10
    print(last_digit)
    num = num//10
# Out:
# 3
# 2
# 1
